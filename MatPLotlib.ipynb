# %% [markdown]
# ### Plot

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6]) #from 0,0 to 6,250
ypoints = np.array([0, 250])


plt.plot(xpoints, ypoints)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
xpoints = np.array([0, 6,12,20]) #from 0,0 to 6,250
ypoints = np.array([0, 25,50,20])


plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([0, 6,12,20]) #from 0,0 to 6,250
ypoints = np.array([0, 25,50,20])


plt.plot(xpoints, ypoints,'o')
plt.show()

# %% [markdown]
# ###If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([0, 1, 4, 9, 16, 25,36,49])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')#https://www.w3schools.com/python/matplotlib_markers.asp
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')#marker|line|color
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'r')#marker|line|color
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,'go:')#color|marker|line
plt.show()

# %% [markdown]
# ###Multiple lines

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid()

plt.show()

# %%
###Gaussiana

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 292.9 kB/s eta 0:00:00m eta 0:00:010:00:04
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np#https://www.geeksforgeeks.org/how-to-plot-a-normal-distribution-with-matplotlib-in-python/
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-20, 20, 0.01)
  
# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
  
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()

# %%
##tentativa 
import math   # This will import math module

print ( math.exp(-45.17))
# Out:
# 2.4150062132629406e-20
